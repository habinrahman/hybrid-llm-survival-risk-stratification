# %% [markdown]
# # Hybrid LLM–Survival — demo notebook
#
# Run from repo root with `jupyter notebook notebooks/demo_notebook.ipynb`.
# The first code cell adds `src/` to `sys.path`.

# %%
import sys
from pathlib import Path
ROOT = Path.cwd().parent if Path.cwd().name == "notebooks" else Path.cwd()
sys.path.insert(0, str(ROOT / "src"))

from hybrid_survival.pipelines.hybrid_pipeline import HybridSurvivalPipeline

pipe = HybridSurvivalPipeline(config_path=str(ROOT / "configs" / "config.yaml"))
pipe.run_full_pipeline()
